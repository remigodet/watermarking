# %%
import tensorflow as tf
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, random_split
from torchvision.utils import make_grid
import numpy as np
import matplotlib.pyplot as plt
from torchvision import datasets, transforms


transform = transforms.ToTensor()


dataset = datasets.CIFAR10(root='./data', download=True, train = True, transform=transform)
test_dataset = datasets.CIFAR10(root='./data', download=True, train = False, transform=transform)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
val_ratio = 0.2
train_set , val_set = random_split(dataset,[int((1-val_ratio)*len(dataset)), int(val_ratio*len(dataset))])

batch_size = 32
train_set = DataLoader(train_set, batch_size=batch_size, shuffle=True, pin_memory=True)
val_set = DataLoader(val_set, batch_size=batch_size, shuffle=True, pin_memory=True)
test_set = DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=True)

# %%
from torch import permute


# def show_batch(dl):
#     for image, label in dl:
#         fig,ax = plt.subplots(figsize = (10,10))
#         print(ax)
#         ax.imshow(make_grid(image, 10))
#         break

# show_batch(train_set)

def show_batch(dl):
    images, labels = iter(dl).next()
    plt.imshow(images[0][0], cmap='gray')
    plt.show()
    plt.imshow(images[0][2], cmap='gray')
    plt.show()
    print(len(labels), len(images))
show_batch(train_set)
# Out:
# 32 32
